# %% [markdown]
# # Exploratory data analysis

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
all_data = pd.read_csv("complaints-2020-01-22_08_24.csv")

# %%
data = all_data.drop(columns=["Complaint ID"]) #...
data
# Out:
#        Date received                                            Product  \
# 0           07/23/19  Credit reporting, credit repair services, or o...
# 1           07/26/19                                    Debt collection
# 2           06/03/19                                    Debt collection
# 3           07/03/19                                    Debt collection
# 4           07/14/19  Credit reporting, credit repair services, or o...
# ...              ...                                                ...
# 485696      05/17/15                                    Debt collection
# 485697      09/03/15                                           Mortgage
# 485698      03/12/16                                      Consumer Loan
# 485699      07/11/16                                      Consumer Loan
# 485700      01/24/17                                    Debt collection
#
#              Sub-product                                              Issue  \
# 0       Credit reporting  Credit monitoring or identity theft protection...
# 1          I do not know                 False statements or representation
# 2          I do not know                  Attempts to collect debt not owed
# 3             Other debt                  Attempts to collect debt not owed
# 4       Credit reporting                        Improper use of your report
# ...                  ...                                                ...
# 485696       Payday loan                 False statements or representation
# 485697    Other mortgage           Loan servicing, payments, escrow account
# 485698      Vehicle loan                         Managing the loan or lease
# 485699      Vehicle loan                         Managing the loan or lease
# 485700     I do not know                              Communication tactics
#
#                                                 Sub-issue  \
# 0       Problem canceling credit monitoring or identif...
# 1                       Attempted to collect wrong amount
# 2                                           Debt was paid
# 3                       Debt was result of identity theft
# 4       Received unsolicited financial product or insu...
# ...                                                   ...
# 485696               Impersonated an attorney or official
# 485697                                               None
# 485698                                               None
# 485699                                               None
# 485700                    Threatened to take legal action
#
#                              Consumer complaint narrative  \
# 0       I have complained many times that the credit r...
# 1       please review the current fraud account and al...
# 2       Called multiple times over the years for a deb...
# 3       I sent in a letter to the company to have them...
# 4       On XX/XX/19 I applied for a Debt Relief Produc...
# ...                                                   ...
# 485696  This account was a payday loan from the XXXX X...
# 485697  We had a mortgage with XXXX that was discharge...
# 485698  I have 2003 XXXX financed through United Auto ...
# 485699  I was on automatic payment for my car loan. In...
# 485700  I recieved a collections call from an unknown ...
#
#                                   Company public response  \
# 0       Company has responded to the consumer and the ...
# 1       Company believes it acted appropriately as aut...
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 485696                                               None
# 485697                                               None
# 485698                                               None
# 485699                                               None
# 485700  Company has responded to the consumer and the ...
#
#                                     Company State ZIP code  \
# 0       Experian Information Solutions Inc.    CA    926XX
# 1           Ideal Collection Services, Inc.    FL    333XX
# 2          ONEMAIN FINANCIAL HOLDINGS, LLC.    FL    327XX
# 3             Diversified Consultants, Inc.    VA    232XX
# 4                   ClearOne Advantage, LLC    PA    191XX
# ...                                     ...   ...      ...
# 485696     Second Round Limited Partnership    ID    836XX
# 485697                        Seterus, Inc.    MD    210XX
# 485698         United PanAm Financial Corp.    TX    750XX
# 485699  NISSAN MOTOR ACCEPTANCE CORPORATION    IL    607XX
# 485700        CMRE Financial Services, Inc.    CA    917XX
#
#                                  Tags Consumer consent provided?  \
# 0                                None           Consent provided
# 1                                None           Consent provided
# 2                                None           Consent provided
# 3                                None           Consent provided
# 4       Older American, Servicemember           Consent provided
# ...                               ...                        ...
# 485696                 Older American           Consent provided
# 485697                           None           Consent provided
# 485698                           None           Consent provided
# 485699                           None           Consent provided
# 485700                           None           Consent provided
#
#        Submitted via Date sent to company     Company response to consumer  \
# 0                Web             07/23/19          Closed with explanation
# 1                Web             07/26/19          Closed with explanation
# 2                Web             06/07/19          Closed with explanation
# 3                Web             07/03/19          Closed with explanation
# 4                Web             07/18/19          Closed with explanation
# ...              ...                  ...                              ...
# 485696           Web             05/17/15                           Closed
# 485697           Web             09/03/15          Closed with explanation
# 485698           Web             03/12/16  Closed with non-monetary relief
# 485699           Web             07/11/16          Closed with explanation
# 485700           Web             01/24/17          Closed with explanation
#
#        Timely response? Consumer disputed?
# 0                   Yes                NaN
# 1                   Yes                NaN
# 2                   Yes                NaN
# 3                   Yes                NaN
# 4                   Yes                NaN
# ...                 ...                ...
# 485696              Yes                 No
# 485697              Yes                 No
# 485698              Yes                 No
# 485699              Yes                 No
# 485700              Yes                 No
#
# [485701 rows x 17 columns]

# %%
data.describe()
# Out:
#        Date received                                            Product  \
# count         485701                                             485701
# unique          1762                                                 18
# top         09/08/17  Credit reporting, credit repair services, or o...
# freq            1890                                             141742
#
#              Sub-product                                 Issue Sub-issue  \
# count             485701                                485701    485701
# unique                76                                   161       217
# top     Credit reporting  Incorrect information on your report      None
# freq              138534                                 77776    127292
#
#                              Consumer complaint narrative  \
# count                                              485701
# unique                                             458819
# top     There are many mistakes appear in my report wi...
# freq                                                 1035
#
#        Company public response        Company   State ZIP code    Tags  \
# count                   485701         485701  485701   485701  485701
# unique                      11           4419      64    10900       4
# top                       None  EQUIFAX, INC.      CA     None    None
# freq                    249763          51881   64769   109125  402436
#
#        Consumer consent provided? Submitted via Date sent to company  \
# count                      485701        485701               485701
# unique                          1             1                 1764
# top              Consent provided           Web             09/08/17
# freq                       485701        485701                 1783
#
#        Company response to consumer Timely response? Consumer disputed?
# count                        485701           485701             164067
# unique                            7                2                  2
# top         Closed with explanation              Yes                 No
# freq                         392553           472502             128260

# %% [markdown]
# ## Analyseren van products en subproducts
#
# Hieronder worden de verschillende producten en subproducten getoond, ten eerste worden alle verschillende klassen productne gevisualiseerd. Gevolgd door alle subproducten per product

# %%
data["Product"].value_counts().plot(kind='barh', title="Products", figsize=(10,10))
plt.show()

# %% [markdown]
# Van sommige categorieën zijn er heel weinig datapunten, deze kunnen misschien zorden weggefilterd

# %% [markdown]
# ### Een voorbeeld van 1 product, nl. Debt collection

# %%
# = data[["Product", "Sub-product"]]
products = data["Product"].unique()

debt = data[data["Product"] == "Debt collection"]
subProdCount = debt["Sub-product"].value_counts()#[:10]

#plt.title("Debt Collection")
plt.pie(subProdCount.values, labels = subProdCount.index, radius = 2, autopct="%.1f%%",)
plt.show()

# %% [markdown]
# ### Alle producten overlopen waarbij er enkel naar d e10 meest voorkomende subproducten wordt gekeken

# %%
names = [x for x in products]
#print(len(names))


fig = plt.figure(figsize = (30,150))
plt.rcParams.update({'font.size': 26})
fig.subplots_adjust(hspace=0.2, wspace=0.8)
i = 0
for n in names:
    i = i + 1
    subplt = fig.add_subplot(9,2,i)
    subplt.set_title(n, y=1.1)
    x = data[data["Product"] == n]
    counts = x["Sub-product"].value_counts()[:10]
    plt.pie(counts.values, labels = counts.index, radius=1)
plt.show()

# %% [markdown]
# Subproduct wordt niet steeds ingevuld, bij sommige producten zijn er veel onderliggende categorieën maar voor anderen is er vaak één dominerende catergorie, of zelfs geen categorie (vb. Credit card).

# %% [markdown]
# ## Analyseren issues en subissues

# %%
#data["Issue"].value_counts().plot(kind='barh', title="Products", figsize=(10,10))

# %% [markdown]
# ### Voor elk product kijken wat de meest voorkomende issues zijn

# %%
names = [x for x in products]
#print(len(names))


fig = plt.figure(figsize = (30,150))
plt.rcParams.update({'font.size': 26})
fig.subplots_adjust(hspace=0.3)
i = 0
for n in names:
    i = i + 1
    ax = fig.add_subplot(18,1,i)
    ax.set_title(n, y=1.1)
    x = data[data["Product"] == n]
    counts = x["Issue"].value_counts()

    y_pos = np.arange(len(counts))
    ax.barh(y_pos, counts.values, align='center')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(counts.index)
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93cb8621ff0c> in <module>
# ----> 1 names = [x for x in products]
#       2 #print(len(names))
#       3
#       4
#       5 fig = plt.figure(figsize = (30,150))
#
# NameError: name 'products' is not defined

# %% [markdown]
# ### Voorbeeld: Debt Collection, issue: Attempts to collect debt not owed
#
# Issue en sub-product zijn niet perse gelinkt (eens nagaan voor meer issues), hier worden alle sub-producten geprint van dat issue

# %%
debtcol = data[(data["Product"] == "Debt collection") & (data["Issue"] == "Attempts to collect debt not owed")]
debtcol["Sub-product"].value_counts()
#data["Consumer complaint narrative"]
# Out:
# Other debt                   9363
# I do not know                5863
# Credit card debt             5545
# Medical debt                 5264
# Auto debt                     751
# Mortgage debt                 600
# Payday loan debt              595
# Federal student loan debt     356
# Private student loan debt     292
# Name: Sub-product, dtype: int64

# %%
debtcol["Sub-issue"].value_counts()
# Out:
# Debt is not yours                                                  14708
# Debt was paid                                                       6413
# Debt was result of identity theft                                   6017
# Debt was already discharged in bankruptcy and is no longer owed     1491
# Name: Sub-issue, dtype: int64
