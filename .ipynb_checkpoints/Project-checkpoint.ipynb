# %% [markdown]
# # Project: Applied Machine Learning
# This notebook was created by Lennart Onghena, Roel Moeyersoons and Tim De Smet.
#
# This project is a collaboration with ML6. They are launching a product that automates parts of big email inboxes.

# %% [markdown]
# # 1. Exploratory Data Analysis (EDA)
#
# ## 1.1. The Data
#
# The features of the data are explained [here](https://cfpb.github.io/api/ccdb/fields.html)

# %%
# All imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix 
from sklearn.decomposition import TruncatedSVD

#%matplotlib inline

# %%
# Use pandas to read csv data into DataFrame
complaints = pd.read_csv('complaints-2020-01-22_08_24.csv')

# %% [markdown]
# Usinge the .info() function the DataFrame we can determine the following about the data:
# * There are a total of 485701 complaints
# * There are a total of 18 features, one of which is numeric
# * There are no missing values, so we don't have to eliminate these datapoints

# %%
complaints.info()
complaints.head(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485701 entries, 0 to 485700
# Data columns (total 18 columns):
# Date received                   485701 non-null object
# Product                         485701 non-null object
# Sub-product                     485701 non-null object
# Issue                           485701 non-null object
# Sub-issue                       485701 non-null object
# Consumer complaint narrative    485701 non-null object
# Company public response         485701 non-null object
# Company                         485701 non-null object
# State                           485701 non-null object
# ZIP code                        485701 non-null object
# Tags                            485701 non-null object
# Consumer consent provided?      485701 non-null object
# Submitted via                   485701 non-null object
# Date sent to company            485701 non-null object
# Company response to consumer    485701 non-null object
# Timely response?                485701 non-null object
# Consumer disputed?              164067 non-null object
# Complaint ID                    485701 non-null int64
# dtypes: int64(1), object(17)
# memory usage: 66.7+ MB
#   Date received                                            Product  \
# 0      07/23/19  Credit reporting, credit repair services, or o...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting  Credit monitoring or identity theft protection...
#
#                                            Sub-issue  \
# 0  Problem canceling credit monitoring or identif...
#
#                         Consumer complaint narrative  \
# 0  I have complained many times that the credit r...
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
#
#                                Company State ZIP code  Tags  \
# 0  Experian Information Solutions Inc.    CA    926XX  None
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web             07/23/19
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       3315279

# %% [markdown]
# First of all, let's check how many complains every product has received

# %%
# Visual representation of the amount of complaints related to certain products
plt.figure(figsize=(14,10))
sns.set()
sns.countplot(y='Product', data=complaints)
plt.show()

# %% [markdown]
# These are the amount of complaints received about the different products and subproducts:

# %%
temp = complaints['Product'].value_counts();

for i in range(len(temp)):
    print(f'\n{temp.index[i]}: {temp[i]}')
    temp2 = (complaints[complaints['Product'] == temp.index[i]]['Sub-product'].value_counts())
    for j in range(len(temp2)):
            print(f'\t\t{temp2.index[j]}: {temp2[j]}')
# Out:
# Credit reporting, credit repair services, or other personal consumer reports: 141742
# 		Credit reporting: 138534
# 		Other personal consumer report: 2481
# 		Credit repair services: 726
# 		Conventional home mortgage: 1
#
# Debt collection: 105765
# 		I do not know: 20639
# 		Other debt: 18699
# 		Credit card debt: 14522
# 		Other (i.e. phone, health club, etc.): 12389
# 		Medical debt: 11239
# 		Credit card: 7520
# 		Medical: 6990
# 		Payday loan debt: 2461
# 		Auto debt: 2319
# 		Payday loan: 2064
# 		Mortgage debt: 1500
# 		Federal student loan debt: 1126
# 		Private student loan debt: 1093
# 		Auto: 1064
# 		Mortgage: 907
# 		Non-federal student loan: 684
# 		Federal student loan: 549
#
# Mortgage: 61094
# 		Conventional home mortgage: 17063
# 		Conventional fixed mortgage: 14562
# 		FHA mortgage: 11341
# 		Conventional adjustable mortgage (ARM): 4975
# 		VA mortgage: 3437
# 		Other mortgage: 3236
# 		Home equity loan or line of credit: 2103
# 		Other type of mortgage: 2011
# 		Home equity loan or line of credit (HELOC): 1690
# 		Reverse mortgage: 676
#
# Credit reporting: 31588
# 		None: 31588
#
# Credit card or prepaid card: 31482
# 		General-purpose credit card or charge card: 23961
# 		Store credit card: 5638
# 		General-purpose prepaid card: 1270
# 		Government benefit card: 335
# 		Gift card: 144
# 		Payroll card: 131
# 		Student prepaid card: 3
#
# Student loan: 24930
# 		Federal student loan servicing: 14292
# 		Non-federal student loan: 5753
# 		Private student loan: 4885
#
# Credit card: 18838
# 		None: 18838
#
# Checking or savings account: 18784
# 		Checking account: 15632
# 		Other banking product or service: 1483
# 		Savings account: 1317
# 		CD (Certificate of Deposit): 338
# 		Personal line of credit: 14
#
# Bank account or service: 14885
# 		Checking account: 10113
# 		Other bank product/service: 3477
# 		Savings account: 887
# 		(CD) Certificate of deposit: 274
# 		Cashing a check without an account: 134
#
# Consumer Loan: 9473
# 		Vehicle loan: 5141
# 		Installment loan: 3093
# 		Vehicle lease: 962
# 		Title loan: 199
# 		Personal line of credit: 44
# 		Pawn loan: 34
#
# Vehicle loan or lease: 8079
# 		Loan: 6632
# 		Lease: 1437
# 		Title loan: 10
#
# Money transfer, virtual currency, or money service: 7735
# 		Domestic (US) money transfer: 2318
# 		Mobile or digital wallet: 1999
# 		Virtual currency: 1648
# 		International money transfer: 1075
# 		Traveler's check or cashier's check: 148
# 		Money order: 140
# 		Check cashing service: 135
# 		Debt settlement: 99
# 		Foreign currency exchange: 97
# 		Refund anticipation check: 76
#
# Payday loan, title loan, or personal loan: 6305
# 		Installment loan: 2571
# 		Payday loan: 1992
# 		Personal line of credit: 1081
# 		Title loan: 647
# 		Pawn loan: 14
#
# Payday loan: 1746
# 		None: 1746
#
# Money transfers: 1497
# 		Domestic (US) money transfer: 861
# 		International money transfer: 636
#
# Prepaid card: 1450
# 		General purpose card: 730
# 		Payroll card: 220
# 		Gift or merchant card: 154
# 		ID prepaid card: 101
# 		Mobile wallet: 85
# 		Government benefit payment card: 80
# 		Other special purpose card: 58
# 		Transit card: 19
# 		Electronic Benefit Transfer / EBT card: 3
#
# Other financial service: 292
# 		Debt settlement: 109
# 		Check cashing: 54
# 		Credit repair: 39
# 		Money order: 35
# 		Traveler’s/Cashier’s checks: 22
# 		Refund anticipation check: 17
# 		Foreign currency exchange: 16
#
# Virtual currency: 16
# 		Domestic (US) money transfer: 15
# 		International money transfer: 1

# %% [markdown]
# Let's look at the Product "Debt Collection" in particular:

# %%
products = complaints["Product"].unique()

debt = complaints[complaints["Product"] == "Debt collection"]
subProdCount = debt["Sub-product"].value_counts()#[:10]

#plt.title("Debt Collection")
patches, texts, autotexts = plt.pie(subProdCount.values, labels = subProdCount.index, radius = 2, autopct="%.1f%%",)
for t in autotexts:
    t.set_fontsize(12)
plt.show()

# %% [markdown]
# To better see the distribution of Sub-Products, the above is also shown in pie plots

# %%
products = complaints["Product"].unique()
names = [x for x in products]

fig = plt.figure(figsize = (15,70))
#plt.rcParams.update({'font.size': 22})
#fig.subplots_adjust(hspace=0.1, wspace=0.3)
i = 0
for n in names:
    i = i + 1
    subplt = fig.add_subplot(9,2,i)
    subplt.set_title(n, y=0.9)
    x = complaints[complaints["Product"] == n]
    counts = x["Sub-product"].value_counts()[:10]
    plt.pie(counts.values, labels = counts.index, radius=0.7)
plt.show()

# %% [markdown]
# The distributions of the sub-issues for each issue are the following:

# %%
temp = complaints['Issue'].value_counts();

for i in range(len(temp)):
    print(f'\n{temp.index[i]}: {temp[i]}')
    temp2 = (complaints[complaints['Issue'] == temp.index[i]]['Sub-issue'].value_counts())
    for j in range(len(temp2)):
            print(f'\t\t{temp2.index[j]}: {temp2[j]}')
# Out:
# Incorrect information on your report: 77776
# 		Information belongs to someone else: 32324
# 		Account status incorrect: 15559
# 		Account information incorrect: 15060
# 		Old information reappears or never goes away: 4282
# 		Personal information incorrect: 4058
# 		Public record information inaccurate: 3900
# 		Information is missing that should be on the report: 1726
# 		None: 512
# 		Information is incorrect: 298
# 		Information that should be on the report is missing: 57
#
# Problem with a credit reporting company's investigation into an existing problem: 38424
# 		Their investigation did not fix an error on your report: 27394
# 		Investigation took more than 30 days: 3027
# 		Difficulty submitting a dispute or getting information about a dispute over the phone: 2877
# 		Was not notified of investigation status or results: 2616
# 		Problem with personal statement of dispute: 2317
# 		None: 193
#
# Attempts to collect debt not owed: 28629
# 		Debt is not yours: 14708
# 		Debt was paid: 6413
# 		Debt was result of identity theft: 6017
# 		Debt was already discharged in bankruptcy and is no longer owed: 1491
#
# Incorrect information on credit report: 21217
# 		Information is not mine: 7102
# 		Account status: 5139
# 		Account terms: 2738
# 		Public record: 2682
# 		Reinserted previously deleted info: 2028
# 		Personal information: 1528
#
# Improper use of your report: 20239
# 		Credit inquiries on your report that you don't recognize: 13131
# 		Reporting company used your report improperly: 6641
# 		Received unsolicited financial product or insurance offers after opting out: 213
# 		Report provided to employer without your written authorization: 204
# 		None: 50
#
# Cont'd attempts collect debt not owed: 17434
# 		Debt is not mine: 10105
# 		Debt was paid: 4684
# 		Debt resulted from identity theft: 1983
# 		Debt was discharged in bankruptcy: 662
#
# Loan servicing, payments, escrow account: 14722
# 		None: 14722
#
# Communication tactics: 13711
# 		Frequent or repeated calls: 7535
# 		You told them to stop contacting you, but they keep trying: 2380
# 		Threatened to take legal action: 1265
# 		Used obscene, profane, or other abusive language: 919
# 		Used obscene/profane/abusive language: 594
# 		Called after sent written cease of comm: 448
# 		Called before 8am or after 9pm: 335
# 		Called outside of 8am-9pm: 235
#
# Trouble during payment process: 13280
# 		None: 13280
#
# Written notification about debt: 12365
# 		Didn't receive enough information to verify debt: 7611
# 		Didn't receive notice of right to dispute: 4323
# 		Notification didn't disclose it was an attempt to collect a debt: 431
#
# Loan modification,collection,foreclosure: 10789
# 		None: 10789
#
# False statements or representation: 10522
# 		Attempted to collect wrong amount: 8145
# 		Impersonated attorney, law enforcement, or government official: 888
# 		Impersonated an attorney or official: 437
# 		Indicated committed crime not paying: 384
# 		Indicated you were committing crime by not paying debt: 360
# 		Told you not to respond to a lawsuit they filed against you: 167
# 		Indicated shouldn't respond to lawsuit: 141
#
# Managing an account: 10200
# 		Deposits and withdrawals: 2844
# 		Problem using a debit or ATM card: 1752
# 		Banking errors: 1365
# 		Fee problem: 1208
# 		Funds not handled or disbursed as instructed: 1199
# 		Problem accessing account: 826
# 		Problem making or receiving payments: 600
# 		Cashing a check: 317
# 		Deposits or withdrawals: 56
# 		Problem with fees or penalties: 17
# 		Problem with renewal: 16
#
# Dealing with your lender or servicer: 9154
# 		Received bad information about your loan: 3299
# 		Trouble with how payments are being handled: 3187
# 		Don't agree with the fees charged: 940
# 		Problem with customer service: 833
# 		Need information about your loan balance or loan terms: 523
# 		Keep getting calls about your loan: 372
#
# Struggling to pay mortgage: 8386
# 		None: 8386
#
# Dealing with my lender or servicer: 7909
# 		Trouble with how payments are handled: 2564
# 		Received bad information about my loan: 1898
# 		Don't agree with fees charged: 1292
# 		Having problems with customer service: 1193
# 		Keep getting calls about my loan: 496
# 		Need information about my balance/terms: 466
#
# Took or threatened to take negative or legal action: 7669
# 		Threatened or suggested your credit would be damaged: 3328
# 		Threatened to sue you for very old debt: 1638
# 		Sued you without properly notifying you of lawsuit: 812
# 		Seized or attempted to seize your property: 698
# 		Threatened to arrest you or take you to jail if you do not pay: 653
# 		Collected or attempted to collect exempt funds: 360
# 		Sued you in a state where you do not live or did not sign for the debt: 172
# 		Threatened to turn you in to immigration or deport you: 8
#
# Disclosure verification of debt: 7590
# 		Not given enough info to verify debt: 4434
# 		Right to dispute notice not received: 2552
# 		Not disclosed as an attempt to collect: 604
#
# Managing the loan or lease: 7521
# 		None: 4519
# 		Billing problem: 1653
# 		Problem with fees charged: 534
# 		Problem with additional products or services purchased with the loan: 357
# 		Problem with the interest rate: 305
# 		Loan sold or transferred to another company: 153
#
# Problem with a purchase shown on your statement: 6977
# 		Credit card company isn't resolving a dispute about a purchase on your statement: 4611
# 		Card was charged for something you did not purchase with the card: 2137
# 		Overcharged for something you did purchase with the card: 229
#
# Account opening, closing, or management: 6347
# 		None: 6347
#
# Credit reporting company's investigation: 5663
# 		No notice of investigation status/result: 2401
# 		Problem with statement of dispute: 1697
# 		Investigation took too long: 962
# 		Inadequate help over the phone: 603
#
# Other features, terms, or problems: 4412
# 		Other problem: 2000
# 		Problem with rewards from credit card: 1131
# 		Problem with customer service: 499
# 		Problem with balance transfer: 278
# 		Privacy issues: 208
# 		Add-on products and services: 190
# 		Credit card company forcing arbitration: 47
# 		Problem with cash advances: 39
# 		Problem with convenience check: 20
#
# Fees or interest: 4198
# 		Problem with fees: 2742
# 		Charged too much interest: 1064
# 		Unexpected increase in interest rate: 392
#
# Problem when making payments: 3942
# 		Problem during payment process: 2265
# 		You never received your bill or did not know a payment was due: 970
# 		None: 707
#
# Application, originator, mortgage broker: 3746
# 		None: 3746
#
# Fraud or scam: 3561
# 		None: 3561
#
# Struggling to repay your loan: 3516
# 		Can't get other flexible options for repaying your loan: 1853
# 		Problem lowering your monthly payments: 1198
# 		Can't temporarily delay making payments: 465
#
# Deposits and withdrawals: 3425
# 		None: 3425
#
# Problem with fraud alerts or security freezes: 3210
# 		None: 3210
#
# Unable to get your credit report or credit score: 3113
# 		Other problem getting your report or credit score: 1840
# 		Problem getting your free annual credit report: 1253
# 		None: 20
#
# Billing disputes: 3102
# 		None: 3102
#
# Can't repay my loan: 3057
# 		Can't decrease my monthly payments: 1557
# 		Can't get flexible payment options: 999
# 		Can't temporarily postpone payments: 501
#
# Applying for a mortgage or refinancing an existing mortgage: 3004
# 		None: 3004
#
# Taking/threatening an illegal action: 2933
# 		Threatened to sue on too old debt: 930
# 		Threatened arrest/jail if do not pay: 711
# 		Sued w/o proper notification of suit: 468
# 		Seized/Attempted to seize property: 426
# 		Attempted to/Collected exempt funds: 251
# 		Sued where didn't live/sign for debt: 147
#
# Improper contact or sharing of info: 2911
# 		Talked to a third party about my debt: 1549
# 		Contacted me after I asked not to: 694
# 		Contacted employer after asked not to: 601
# 		Contacted me instead of my attorney: 67
#
# Closing on a mortgage: 2640
# 		None: 2640
#
# Getting a credit card: 2600
# 		Card opened as result of identity theft or fraud: 1097
# 		Application denied: 808
# 		Sent card you never applied for: 334
# 		Delay in processing application: 225
# 		Problem getting a working replacement card: 136
#
# Struggling to pay your loan: 2597
# 		None: 1063
# 		Loan balance remaining after the vehicle is repossessed and sold: 550
# 		Denied request to lower payments: 478
# 		Lender trying to repossess or disable the vehicle: 452
# 		Problem after you declared or threatened to declare bankruptcy: 54
#
# Closing your account: 2460
# 		Company closed your account: 1831
# 		Can't close your account: 629
#
# Problems when you are unable to pay: 2456
# 		None: 2456
#
# Advertising and marketing, including promotional offers: 2399
# 		Didn't receive advertised or promotional terms: 1452
# 		Confusing or misleading advertising about the credit card: 947
#
# Closing an account: 2379
# 		Company closed your account: 1022
# 		Funds not received from closed account: 581
# 		Can't close your account: 572
# 		Fees charged for closing account: 204
#
# Unable to get credit report/credit score: 2252
# 		Problem getting my free annual report: 1214
# 		Problem getting report or credit score: 1038
#
# Settlement process and costs: 2250
# 		None: 2250
#
# Credit monitoring or identity theft protection services: 2223
# 		Billing dispute for services: 874
# 		Problem canceling credit monitoring or identify theft protection service: 474
# 		Didn't receive services that were advertised: 380
# 		Problem with product or service terms changing: 352
# 		Received unwanted marketing or advertising: 121
# 		None: 22
#
# Opening an account: 2208
# 		Didn't receive terms that were advertised: 1063
# 		Unable to open an account: 661
# 		Account opened as a result of fraud: 351
# 		Confusing or missing disclosures: 133
#
# Problem with a lender or other company charging your account: 2144
# 		Transaction was not authorized: 1690
# 		Money was taken from your account on the wrong day or for the wrong amount: 243
# 		Can't stop withdrawals from your account: 211
#
# Problems caused by my funds being low: 2084
# 		None: 2084
#
# Threatened to contact someone or share information improperly: 2001
# 		Talked to a third-party about your debt: 1053
# 		Contacted your employer: 579
# 		Contacted you after you asked them to stop: 337
# 		Contacted you instead of your attorney: 32
#
# Other: 1940
# 		None: 1940
#
# Charged fees or interest you didn't expect: 1770
# 		None: 1770
#
# Problem caused by your funds being low: 1724
# 		Overdrafts and overdraft fees: 1143
# 		Non-sufficient funds and associated fees: 398
# 		Bounced checks or returned payments: 108
# 		Late or other fees: 75
#
# Identity theft / Fraud / Embezzlement: 1723
# 		None: 1723
#
# Money was not available when promised: 1621
# 		None: 1621
#
# Using a debit or ATM card: 1597
# 		None: 1597
#
# Taking out the loan or lease: 1560
# 		None: 1560
#
# Improper use of my credit report: 1520
# 		Report improperly shared by CRC: 1415
# 		Report shared with employer w/o consent: 53
# 		Received marketing offer after opted out: 52
#
# Problems at the end of the loan or lease: 1519
# 		Unable to receive car title or other problem after the loan is paid off: 453
# 		Problem with paying off the loan: 385
# 		Excess mileage, damage, or wear fees, or other problem after the lease is finish: 209
# 		Problem while selling or giving up the vehicle: 165
# 		Termination fees or other problem when ending the lease early: 137
# 		Problem related to refinancing: 101
# 		Problem when attempting to purchase vehicle at the end of the lease: 48
# 		Problem extending the lease: 21
#
# Other transaction problem: 1482
# 		None: 1482
#
# Closing/Cancelling account: 1440
# 		None: 1440
#
# Making/receiving payments, sending money: 1432
# 		None: 1432
#
# Trouble using your card: 1307
# 		Can't use card to make purchases: 836
# 		Credit card company won't increase or decrease your credit limit: 453
# 		Account sold or transferred to another company: 18
#
# Credit decision / Underwriting: 1289
# 		None: 1289
#
# Customer service / Customer relations: 973
# 		None: 973
#
# Getting a loan or lease: 943
# 		Fraudulent loan: 386
# 		Confusing or misleading advertising or marketing: 147
# 		Changes in terms mid-deal or after closing: 133
# 		Credit denial: 130
# 		High-pressure sales tactics: 53
# 		Problem with signing the paperwork: 31
# 		Problem with additional add-on products or services purchased with the loan: 30
# 		Problem with a trade-in: 19
# 		Confusing or misleading advertising: 14
#
# Credit monitoring or identity protection: 936
# 		Problem with fraud alerts: 292
# 		Billing dispute: 278
# 		Account terms and changes: 165
# 		Problem cancelling or closing account: 148
# 		Receiving unwanted marketing/advertising: 53
#
# Rewards: 900
# 		None: 900
#
# Charged fees or interest I didn't expect: 852
# 		None: 852
#
# Delinquent account: 834
# 		None: 834
#
# Advertising and marketing: 830
# 		None: 830
#
# APR or interest rate: 785
# 		None: 785
#
# Late fee: 771
# 		None: 771
#
# Unexpected or other fees: 724
# 		None: 724
#
# Credit card protection / Debt protection: 712
# 		None: 712
#
# Problem with a purchase or transfer: 691
# 		Card company isn't resolving a dispute about a purchase or transfer: 426
# 		Charged for a purchase or transfer you did not make with the card: 251
# 		Overcharged for a purchase or transfer you did make with the card: 14
#
# Transaction issue: 681
# 		None: 681
#
# Shopping for a loan or lease: 662
# 		None: 662
#
# Problem with the payoff process at the end of the loan: 633
# 		None: 633
#
# Billing statement: 620
# 		None: 620
#
# Unauthorized transactions or other transaction problem: 558
# 		None: 558
#
# Struggling to pay your bill: 551
# 		Credit card company won't work with you while you're going through financial hardship: 486
# 		Problem lowering your monthly payments: 36
# 		Filed for bankruptcy: 29
#
# Unauthorized transactions/trans. issues: 543
# 		None: 543
#
# Payoff process: 513
# 		None: 513
#
# Credit determination: 506
# 		None: 506
#
# Other fee: 502
# 		None: 502
#
# Unsolicited issuance of credit card: 491
# 		None: 491
#
# Managing, opening, or closing your mobile wallet account: 473
# 		None: 473
#
# Other transaction issues: 471
# 		None: 471
#
# Getting a loan: 465
# 		Fraudulent loan: 132
# 		Can't qualify for a loan: 127
# 		Confusing or misleading advertising: 75
# 		Qualify for a better loan than offered: 56
# 		Denied loan: 34
# 		Problem with the interest rate: 29
# 		Qualified for a better loan than the one offered: 8
# 		Problem with signing the paperwork: 4
#
# Credit line increase/decrease: 451
# 		None: 451
#
# Problem with a company's investigation into an existing issue: 447
# 		Their investigation did not fix an error on your report: 147
# 		Difficulty submitting a dispute or getting information about a dispute over the phone: 127
# 		Problem with personal statement of dispute: 74
# 		Was not notified of investigation status or results: 67
# 		Investigation took more than 30 days: 32
#
# Trouble using the card: 412
# 		Trouble using the card to spend money in a store or online: 210
# 		Trouble getting information about the card: 57
# 		Problem using the card to withdraw money from an ATM: 51
# 		Problem with direct deposit: 48
# 		Trouble using the card to pay a bill: 20
# 		Problem adding money: 18
# 		Problem with a check written from your prepaid card account: 6
# 		Trouble using the card to send money to another person: 2
#
# Other service problem: 399
# 		None: 399
#
# Getting the loan: 389
# 		None: 389
#
# Managing, opening, or closing account: 386
# 		None: 386
#
# Can't contact lender: 372
# 		None: 372
#
# Problem with customer service: 321
# 		None: 321
#
# Confusing or missing disclosures: 319
# 		None: 319
#
# Balance transfer: 298
# 		None: 298
#
# Problem getting a card or closing an account: 272
# 		Trouble closing card: 131
# 		Trouble getting, activating, or registering a card: 83
# 		Trouble getting a working replacement card: 49
# 		Don't want a card provided by your employer or the government: 9
#
# Identity theft protection or other monitoring services: 271
# 		Didn't receive services that were advertised: 77
# 		Problem canceling credit monitoring or identify theft protection service: 68
# 		Problem with product or service terms changing: 52
# 		Billing dispute for services: 43
# 		Received unwanted marketing or advertising: 31
#
# Wrong amount charged or received: 248
# 		None: 248
#
# Received a loan I didn't apply for: 210
# 		None: 210
#
# Confusing or misleading advertising or marketing: 192
# 		None: 192
#
# Applying for a mortgage: 190
# 		None: 190
#
# Getting a line of credit: 190
# 		None: 190
#
# Problem with additional add-on products or services: 183
# 		None: 183
#
# Can't contact lender or servicer: 172
# 		None: 172
#
# Can't stop charges to bank account: 166
# 		None: 166
#
# Received a loan you didn't apply for: 158
# 		None: 158
#
# Payment to acct not credited: 151
# 		None: 151
#
# Can't stop withdrawals from your bank account: 148
# 		None: 148
#
# Other service issues: 138
# 		None: 138
#
# Loan payment wasn't credited to your account: 133
# 		None: 133
#
# Application processing delay: 107
# 		None: 107
#
# Charged bank acct wrong day or amt: 106
# 		None: 106
#
# Privacy: 105
# 		None: 105
#
# Sale of account: 98
# 		None: 98
#
# Bankruptcy: 96
# 		None: 96
#
# Vehicle was repossessed or sold the vehicle: 95
# 		None: 95
#
# Adding money: 92
# 		None: 92
#
# Money was taken from your bank account on the wrong day or for the wrong amount: 92
# 		None: 92
#
# Applied for loan/did not receive money: 85
# 		None: 85
#
# Forbearance / Workout plans: 85
# 		None: 85
#
# Problem adding money: 85
# 		None: 85
#
# Arbitration: 83
# 		None: 83
#
# Excessive fees: 81
# 		None: 81
#
# Fees: 77
# 		None: 77
#
# Advertising: 77
# 		Confusing or misleading advertising about the card: 59
# 		Changes in terms from what was offered or advertised: 18
#
# Was approved for a loan, but didn't receive the money: 65
# 		None: 65
#
# Lost or stolen check: 64
# 		None: 64
#
# Incorrect/missing disclosures or info: 58
# 		None: 58
#
# Lost or stolen money order: 56
# 		None: 56
#
# Customer service/Customer relations: 55
# 		None: 55
#
# Balance transfer fee: 51
# 		None: 51
#
# Cash advance: 44
# 		None: 44
#
# Cash advance fee: 41
# 		None: 41
#
# Convenience checks: 37
# 		None: 37
#
# Vehicle was damaged or destroyed the vehicle: 36
# 		None: 36
#
# Overlimit fee: 31
# 		None: 31
#
# Lender repossessed or sold the vehicle: 31
# 		None: 31
#
# Credit limit changed: 31
# 		None: 31
#
# Problem with cash advance: 28
# 		None: 28
#
# Incorrect exchange rate: 27
# 		None: 27
#
# Advertising, marketing or disclosures: 25
# 		None: 25
#
# Unexpected/Other fees: 22
# 		None: 22
#
# Overdraft, savings or rewards features: 17
# 		None: 17
#
# Was approved for a loan, but didn't receive money: 17
# 		None: 17
#
# Account terms and changes: 17
# 		None: 17
#
# Managing the line of credit: 16
# 		None: 16
#
# Disclosures: 13
# 		None: 13
#
# Problem with overdraft: 13
# 		Overdraft charges: 12
# 		Was signed up for overdraft on card, but don't want to be: 1
#
# Overdraft, savings, or rewards features: 12
# 		None: 12
#
# Shopping for a line of credit: 10
# 		None: 10
#
# Lender sold the property: 3
# 		None: 3
#
# Property was sold: 3
# 		None: 3
#
# Lender damaged or destroyed vehicle: 2
# 		None: 2
#
# Problem with an overdraft: 2
# 		Was signed up for overdraft on card, but don't want to be: 2
#
# Property was damaged or destroyed property: 2
# 		None: 2
#
# Lender damaged or destroyed property: 1
# 		None: 1

# %% [markdown]
# Let's visualize the issues by product:

# %%
products = complaints["Product"].unique()
names = [x for x in products]

fig = plt.figure(figsize = (10,75))
#plt.rcParams.update({'font.size': 26})
fig.subplots_adjust(hspace=0.5)
i = 0
for n in names:
    i = i + 1
    ax = fig.add_subplot(18,1,i)
    ax.set_title(n, y=1.1)
    x = complaints[complaints["Product"] == n]
    counts = x["Issue"].value_counts()

    y_pos = np.arange(len(counts))
    ax.barh(y_pos, counts.values, align='center')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(counts.index)
    
plt.show()

# %% [markdown]
# As seen above, some issues appear in several products. Below the issues are printed along with each product category it appears in

# %%
temp = complaints['Issue'].value_counts();

for i in range(len(temp)):
    print(f'\n{temp.index[i]}: {temp[i]}')
    temp2 = (complaints[complaints['Issue'] == temp.index[i]]['Product'].value_counts())
    for j in range(len(temp2)):
            print(f'\t\t{temp2.index[j]}: {temp2[j]}')
# Out:
# Incorrect information on your report: 77776
# 		Credit reporting, credit repair services, or other personal consumer reports: 75050
# 		Credit card or prepaid card: 761
# 		Vehicle loan or lease: 639
# 		Student loan: 531
# 		Mortgage: 511
# 		Payday loan, title loan, or personal loan: 219
# 		Checking or savings account: 65
#
# Problem with a credit reporting company's investigation into an existing problem: 38424
# 		Credit reporting, credit repair services, or other personal consumer reports: 37107
# 		Credit card or prepaid card: 496
# 		Vehicle loan or lease: 317
# 		Student loan: 223
# 		Mortgage: 193
# 		Payday loan, title loan, or personal loan: 72
# 		Checking or savings account: 16
#
# Attempts to collect debt not owed: 28629
# 		Debt collection: 28629
#
# Incorrect information on credit report: 21217
# 		Credit reporting: 21217
#
# Improper use of your report: 20239
# 		Credit reporting, credit repair services, or other personal consumer reports: 19878
# 		Credit card or prepaid card: 132
# 		Vehicle loan or lease: 74
# 		Payday loan, title loan, or personal loan: 67
# 		Mortgage: 50
# 		Student loan: 21
# 		Checking or savings account: 17
#
# Cont'd attempts collect debt not owed: 17434
# 		Debt collection: 17434
#
# Loan servicing, payments, escrow account: 14722
# 		Mortgage: 14722
#
# Communication tactics: 13711
# 		Debt collection: 13711
#
# Trouble during payment process: 13280
# 		Mortgage: 13280
#
# Written notification about debt: 12365
# 		Debt collection: 12365
#
# Loan modification,collection,foreclosure: 10789
# 		Mortgage: 10789
#
# False statements or representation: 10522
# 		Debt collection: 10522
#
# Managing an account: 10200
# 		Checking or savings account: 10200
#
# Dealing with your lender or servicer: 9154
# 		Student loan: 9153
# 		Credit reporting, credit repair services, or other personal consumer reports: 1
#
# Struggling to pay mortgage: 8386
# 		Mortgage: 8385
# 		Credit reporting, credit repair services, or other personal consumer reports: 1
#
# Dealing with my lender or servicer: 7909
# 		Student loan: 7909
#
# Took or threatened to take negative or legal action: 7669
# 		Debt collection: 7669
#
# Disclosure verification of debt: 7590
# 		Debt collection: 7590
#
# Managing the loan or lease: 7521
# 		Consumer Loan: 4519
# 		Vehicle loan or lease: 3002
#
# Problem with a purchase shown on your statement: 6977
# 		Credit card or prepaid card: 6977
#
# Account opening, closing, or management: 6347
# 		Bank account or service: 6347
#
# Credit reporting company's investigation: 5663
# 		Credit reporting: 5663
#
# Other features, terms, or problems: 4412
# 		Credit card or prepaid card: 4412
#
# Fees or interest: 4198
# 		Credit card or prepaid card: 4198
#
# Problem when making payments: 3942
# 		Credit card or prepaid card: 3234
# 		Payday loan, title loan, or personal loan: 707
# 		Credit reporting, credit repair services, or other personal consumer reports: 1
#
# Application, originator, mortgage broker: 3746
# 		Mortgage: 3746
#
# Fraud or scam: 3561
# 		Money transfer, virtual currency, or money service: 2363
# 		Money transfers: 508
# 		Prepaid card: 310
# 		Credit reporting, credit repair services, or other personal consumer reports: 249
# 		Other financial service: 126
# 		Virtual currency: 5
#
# Struggling to repay your loan: 3516
# 		Student loan: 3516
#
# Deposits and withdrawals: 3425
# 		Bank account or service: 3425
#
# Problem with fraud alerts or security freezes: 3210
# 		Credit reporting, credit repair services, or other personal consumer reports: 3158
# 		Checking or savings account: 18
# 		Credit card or prepaid card: 9
# 		Student loan: 8
# 		Payday loan, title loan, or personal loan: 7
# 		Vehicle loan or lease: 5
# 		Mortgage: 5
#
# Unable to get your credit report or credit score: 3113
# 		Credit reporting, credit repair services, or other personal consumer reports: 3041
# 		Credit card or prepaid card: 21
# 		Mortgage: 20
# 		Vehicle loan or lease: 17
# 		Student loan: 7
# 		Checking or savings account: 4
# 		Payday loan, title loan, or personal loan: 3
#
# Billing disputes: 3102
# 		Credit card: 3102
#
# Can't repay my loan: 3057
# 		Student loan: 3057
#
# Applying for a mortgage or refinancing an existing mortgage: 3004
# 		Mortgage: 3004
#
# Taking/threatening an illegal action: 2933
# 		Debt collection: 2933
#
# Improper contact or sharing of info: 2911
# 		Debt collection: 2911
#
# Closing on a mortgage: 2640
# 		Mortgage: 2638
# 		Credit reporting, credit repair services, or other personal consumer reports: 2
#
# Getting a credit card: 2600
# 		Credit card or prepaid card: 2599
# 		Credit reporting, credit repair services, or other personal consumer reports: 1
#
# Struggling to pay your loan: 2597
# 		Vehicle loan or lease: 1534
# 		Payday loan, title loan, or personal loan: 1063
#
# Closing your account: 2460
# 		Credit card or prepaid card: 2460
#
# Problems when you are unable to pay: 2456
# 		Consumer Loan: 2456
#
# Advertising and marketing, including promotional offers: 2399
# 		Credit card or prepaid card: 2399
#
# Closing an account: 2379
# 		Checking or savings account: 2379
#
# Unable to get credit report/credit score: 2252
# 		Credit reporting: 2252
#
# Settlement process and costs: 2250
# 		Mortgage: 2250
#
# Credit monitoring or identity theft protection services: 2223
# 		Credit reporting, credit repair services, or other personal consumer reports: 2054
# 		Credit card or prepaid card: 43
# 		Student loan: 40
# 		Vehicle loan or lease: 32
# 		Payday loan, title loan, or personal loan: 24
# 		Mortgage: 22
# 		Checking or savings account: 8
#
# Opening an account: 2208
# 		Checking or savings account: 2208
#
# Problem with a lender or other company charging your account: 2144
# 		Checking or savings account: 2144
#
# Problems caused by my funds being low: 2084
# 		Bank account or service: 2084
#
# Threatened to contact someone or share information improperly: 2001
# 		Debt collection: 2001
#
# Other: 1940
# 		Credit card: 1940
#
# Charged fees or interest you didn't expect: 1770
# 		Payday loan, title loan, or personal loan: 1770
#
# Problem caused by your funds being low: 1724
# 		Checking or savings account: 1724
#
# Identity theft / Fraud / Embezzlement: 1723
# 		Credit card: 1723
#
# Money was not available when promised: 1621
# 		Money transfer, virtual currency, or money service: 1361
# 		Money transfers: 259
# 		Virtual currency: 1
#
# Using a debit or ATM card: 1597
# 		Bank account or service: 1597
#
# Taking out the loan or lease: 1560
# 		Consumer Loan: 1560
#
# Improper use of my credit report: 1520
# 		Credit reporting: 1520
#
# Problems at the end of the loan or lease: 1519
# 		Vehicle loan or lease: 1519
#
# Other transaction problem: 1482
# 		Money transfer, virtual currency, or money service: 1482
#
# Closing/Cancelling account: 1440
# 		Credit card: 1440
#
# Making/receiving payments, sending money: 1432
# 		Bank account or service: 1432
#
# Trouble using your card: 1307
# 		Credit card or prepaid card: 1307
#
# Credit decision / Underwriting: 1289
# 		Mortgage: 1289
#
# Customer service / Customer relations: 973
# 		Credit card: 973
#
# Getting a loan or lease: 943
# 		Vehicle loan or lease: 940
# 		Credit reporting, credit repair services, or other personal consumer reports: 3
#
# Credit monitoring or identity protection: 936
# 		Credit reporting: 936
#
# Rewards: 900
# 		Credit card: 900
#
# Charged fees or interest I didn't expect: 852
# 		Payday loan: 752
# 		Consumer Loan: 100
#
# Delinquent account: 834
# 		Credit card: 834
#
# Advertising and marketing: 830
# 		Credit card: 818
# 		Other financial service: 12
#
# APR or interest rate: 785
# 		Credit card: 785
#
# Late fee: 771
# 		Credit card: 771
#
# Unexpected or other fees: 724
# 		Credit card or prepaid card: 416
# 		Money transfer, virtual currency, or money service: 218
# 		Credit reporting, credit repair services, or other personal consumer reports: 90
#
# Credit card protection / Debt protection: 712
# 		Credit card: 712
#
# Problem with a purchase or transfer: 691
# 		Credit card or prepaid card: 691
#
# Transaction issue: 681
# 		Credit card: 681
#
# Shopping for a loan or lease: 662
# 		Consumer Loan: 662
#
# Problem with the payoff process at the end of the loan: 633
# 		Payday loan, title loan, or personal loan: 632
# 		Credit reporting, credit repair services, or other personal consumer reports: 1
#
# Billing statement: 620
# 		Credit card: 620
#
# Unauthorized transactions or other transaction problem: 558
# 		Money transfer, virtual currency, or money service: 558
#
# Struggling to pay your bill: 551
# 		Credit card or prepaid card: 551
#
# Unauthorized transactions/trans. issues: 543
# 		Prepaid card: 543
#
# Payoff process: 513
# 		Credit card: 513
#
# Credit determination: 506
# 		Credit card: 506
#
# Other fee: 502
# 		Credit card: 502
#
# Unsolicited issuance of credit card: 491
# 		Credit card: 491
#
# Managing, opening, or closing your mobile wallet account: 473
# 		Money transfer, virtual currency, or money service: 473
#
# Other transaction issues: 471
# 		Money transfers: 469
# 		Virtual currency: 2
#
# Getting a loan: 465
# 		Student loan: 465
#
# Credit line increase/decrease: 451
# 		Credit card: 451
#
# Problem with a company's investigation into an existing issue: 447
# 		Credit reporting, credit repair services, or other personal consumer reports: 447
#
# Trouble using the card: 412
# 		Credit card or prepaid card: 412
#
# Other service problem: 399
# 		Money transfer, virtual currency, or money service: 399
#
# Getting the loan: 389
# 		Payday loan, title loan, or personal loan: 389
#
# Managing, opening, or closing account: 386
# 		Prepaid card: 386
#
# Can't contact lender: 372
# 		Payday loan: 339
# 		Consumer Loan: 33
#
# Problem with customer service: 321
# 		Money transfer, virtual currency, or money service: 162
# 		Credit reporting, credit repair services, or other personal consumer reports: 159
#
# Confusing or missing disclosures: 319
# 		Money transfer, virtual currency, or money service: 259
# 		Credit reporting, credit repair services, or other personal consumer reports: 60
#
# Balance transfer: 298
# 		Credit card: 298
#
# Problem getting a card or closing an account: 272
# 		Credit card or prepaid card: 272
#
# Identity theft protection or other monitoring services: 271
# 		Credit reporting, credit repair services, or other personal consumer reports: 271
#
# Wrong amount charged or received: 248
# 		Money transfer, virtual currency, or money service: 175
# 		Money transfers: 73
#
# Received a loan I didn't apply for: 210
# 		Payday loan: 202
# 		Consumer Loan: 8
#
# Confusing or misleading advertising or marketing: 192
# 		Credit reporting, credit repair services, or other personal consumer reports: 123
# 		Money transfer, virtual currency, or money service: 69
#
# Applying for a mortgage: 190
# 		Mortgage: 190
#
# Getting a line of credit: 190
# 		Payday loan, title loan, or personal loan: 189
# 		Checking or savings account: 1
#
# Problem with additional add-on products or services: 183
# 		Payday loan, title loan, or personal loan: 183
#
# Can't contact lender or servicer: 172
# 		Payday loan, title loan, or personal loan: 172
#
# Can't stop charges to bank account: 166
# 		Payday loan: 159
# 		Consumer Loan: 7
#
# Received a loan you didn't apply for: 158
# 		Payday loan, title loan, or personal loan: 158
#
# Payment to acct not credited: 151
# 		Payday loan: 122
# 		Consumer Loan: 29
#
# Can't stop withdrawals from your bank account: 148
# 		Payday loan, title loan, or personal loan: 148
#
# Other service issues: 138
# 		Money transfers: 130
# 		Virtual currency: 8
#
# Loan payment wasn't credited to your account: 133
# 		Payday loan, title loan, or personal loan: 133
#
# Application processing delay: 107
# 		Credit card: 107
#
# Charged bank acct wrong day or amt: 106
# 		Payday loan: 102
# 		Consumer Loan: 4
#
# Privacy: 105
# 		Credit card: 105
#
# Sale of account: 98
# 		Credit card: 98
#
# Bankruptcy: 96
# 		Credit card: 96
#
# Vehicle was repossessed or sold the vehicle: 95
# 		Payday loan, title loan, or personal loan: 95
#
# Adding money: 92
# 		Prepaid card: 92
#
# Money was taken from your bank account on the wrong day or for the wrong amount: 92
# 		Payday loan, title loan, or personal loan: 92
#
# Applied for loan/did not receive money: 85
# 		Payday loan: 70
# 		Consumer Loan: 15
#
# Forbearance / Workout plans: 85
# 		Credit card: 85
#
# Problem adding money: 85
# 		Money transfer, virtual currency, or money service: 85
#
# Arbitration: 83
# 		Credit card: 83
#
# Excessive fees: 81
# 		Credit reporting, credit repair services, or other personal consumer reports: 45
# 		Other financial service: 36
#
# Fees: 77
# 		Prepaid card: 77
#
# Advertising: 77
# 		Credit card or prepaid card: 77
#
# Was approved for a loan, but didn't receive the money: 65
# 		Payday loan, title loan, or personal loan: 65
#
# Lost or stolen check: 64
# 		Money transfer, virtual currency, or money service: 50
# 		Other financial service: 14
#
# Incorrect/missing disclosures or info: 58
# 		Money transfers: 58
#
# Lost or stolen money order: 56
# 		Money transfer, virtual currency, or money service: 45
# 		Other financial service: 11
#
# Customer service/Customer relations: 55
# 		Other financial service: 55
#
# Balance transfer fee: 51
# 		Credit card: 51
#
# Cash advance: 44
# 		Credit card: 44
#
# Cash advance fee: 41
# 		Credit card: 41
#
# Convenience checks: 37
# 		Credit card: 37
#
# Vehicle was damaged or destroyed the vehicle: 36
# 		Payday loan, title loan, or personal loan: 36
#
# Overlimit fee: 31
# 		Credit card: 31
#
# Lender repossessed or sold the vehicle: 31
# 		Consumer Loan: 31
#
# Credit limit changed: 31
# 		Payday loan, title loan, or personal loan: 31
#
# Problem with cash advance: 28
# 		Payday loan, title loan, or personal loan: 28
#
# Incorrect exchange rate: 27
# 		Money transfer, virtual currency, or money service: 24
# 		Other financial service: 3
#
# Advertising, marketing or disclosures: 25
# 		Prepaid card: 25
#
# Unexpected/Other fees: 22
# 		Other financial service: 22
#
# Overdraft, savings or rewards features: 17
# 		Prepaid card: 17
#
# Was approved for a loan, but didn't receive money: 17
# 		Payday loan, title loan, or personal loan: 17
#
# Account terms and changes: 17
# 		Consumer Loan: 17
#
# Managing the line of credit: 16
# 		Consumer Loan: 16
#
# Disclosures: 13
# 		Other financial service: 13
#
# Problem with overdraft: 13
# 		Credit card or prepaid card: 13
#
# Overdraft, savings, or rewards features: 12
# 		Money transfer, virtual currency, or money service: 12
#
# Shopping for a line of credit: 10
# 		Consumer Loan: 10
#
# Lender sold the property: 3
# 		Consumer Loan: 3
#
# Property was sold: 3
# 		Payday loan, title loan, or personal loan: 3
#
# Lender damaged or destroyed vehicle: 2
# 		Consumer Loan: 2
#
# Problem with an overdraft: 2
# 		Credit card or prepaid card: 2
#
# Property was damaged or destroyed property: 2
# 		Payday loan, title loan, or personal loan: 2
#
# Lender damaged or destroyed property: 1
# 		Consumer Loan: 1

# %% [markdown]
# ## 1.2. Problems
#
# * Sub-product and Sub-issue not always present
# * Product columns are overlapping, we could change to:
#     * Mortgage (cat A)
#     * Loan (cat B)
#         * Consumer Loan
#         * Payday loan
#         * Payday loan, title loan, or personal loan
#         * Student loan
#         * Vehicle loan or lease
#     * Card (cat C)
#         * Credit card
#         * Credit card or prepaid card
#         * Prepaid card
#     * Credit (cat D)
#         * Credit reporting
#         * Credit reporting, credit repair services, or other personal consumer reports
#     * Other financial service (cat E)
#         * Money transfer, virtual currency, or money service
#         * Money transfers
#         * Virtual currency
#         * Bank account or service
#         * Checking or savings account
#     * Debt collection (cat F)
# * Also overlap between issues
# * Some Products have the same issue names

# %% [markdown]
# In the first iteration we are going to
# * remove seemingly unnecessairy data and simplify dataset
# * Extract features
# * One hot encoding for categorical features
# * remove imbalances
# * pairplot
# * catplot
# * train test split
#
# * Classify incoming messages to some basic issue types
#
# ## 1.3. Simplification

# %%
# simplifying dataset
simp_map = {
    'Debt collection' : 'F', 
    'Payday loan' : 'B', 
    'Mortgage' : 'A', 
    'Bank account or service' : 'E', 
    'Consumer Loan' : 'B', 
    'Other financial service' : 'E', 
    'Vehicle loan or lease' : 'B',
    'Payday loan, title loan, or personal loan' : 'B', 
    'Money transfers' : 'E', 
    'Student loan' : 'B', 
    'Virtual currency': 'E', 
    'Credit reporting, credit repair services, or other personal consumer reports' : 'D', 
    'Credit card' : 'C', 
    'Checking or savings account' : 'E', 
    'Prepaid card' : 'C', 
    'Money transfer, virtual currency, or money service' : 'E', 
    'Credit reporting': 'D', 
    'Credit card or prepaid card' : 'C'}

data = complaints[['Product', 'Consumer complaint narrative']].copy()
data['TARGET'] = data['Product'].map(simp_map)

plt.figure(figsize=(14,10))
sns.set()
sns.countplot(y='TARGET', data=data)
plt.show()

# %% [markdown]
# We can see that the dataset is imbalanced, this could cause the model to collapse to the trivial solution of always returning the same prediction. We will resolve this by subsampling in order to flatten the distribution:

# %%
for c in ['A', 'B', 'C', 'D', 'E', 'F']:
    if data[data['TARGET'] == c].shape[0] > 70000:
        data = pd.concat(objs=[data[data['TARGET'] == c].sample(n=70000), data[data['TARGET'] != c]])

plt.figure(figsize=(14,10))
sns.set()
sns.countplot(y='TARGET', data=data)
plt.show()

# %% [markdown]
# ## 1.4. Feature extraction and behind the screen preprocessing

# %%
# %%time
data = data.sample(10000)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(data['Consumer complaint narrative'])
print(X_train_counts.shape)

tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print(X_train_tfidf.shape)
# Out:
# (10000, 20656)
# (10000, 20656)
# CPU times: user 2 s, sys: 74.4 ms, total: 2.07 s
# Wall time: 2.5 s

# %% [markdown]
# ## 1.5. Dimensionality Reduction
# The tfidf vector is too large to work with. The train_test_split overflowed the memory because of .todense() function.
#
# The first thing we tried was PCA but here too the memory overflowed and interrupted the kernel. However we came upon TruncatedSVD:
# [source](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html)
# >In particular, truncated SVD works on term count/tf-idf matrices as returned by the vectorizers in sklearn.feature_extraction.text. In that context, it is known as latent semantic analysis (LSA).
#
# Hyperparameter 100 was chosen because this is what the document recommends for LSA.

# %%
# %%time
svd = TruncatedSVD(n_components=500)
tfidf_reduced = svd.fit_transform(X_train_tfidf)
print(tfidf_reduced.shape)
print(type(tfidf_reduced))
# Out:
# (10000, 50)
# <class 'numpy.ndarray'>
# CPU times: user 2.02 s, sys: 127 ms, total: 2.15 s
# Wall time: 1.82 s

# %% [markdown]
# ## 1.6. Train Test Split

# %%
# %%time
y = data['TARGET']
x = tfidf_reduced
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)
# Out:
# CPU times: user 5.06 ms, sys: 1.44 ms, total: 6.5 ms
# Wall time: 6.91 ms

# %% [markdown]
# ## 1.7. K-nearest neighbors

# %%
# %%time
knn = KNeighborsClassifier(algorithm='kd_tree')
knn.fit(x_train, y_train)
predictions = knn.predict(x_test)
# Out:
# CPU times: user 2.58 s, sys: 39.2 ms, total: 2.62 s
# Wall time: 3.4 s

# %% [markdown]
# ### 1.7.1. Hyper Parameter Tuning (K)

# %%
# %%time
accuracies = []
for k in range(1,50):
    knn = KNeighborsClassifier(n_neighbors=k, algorithm='kd_tree')
    knn.fit(x_train, y_train)
    predictions = knn.predict(x_test)
    accuracies.append((predictions == y_test).mean())
plt.plot(accuracies)
# Out:
# CPU times: user 1min 57s, sys: 1.29 s, total: 1min 59s
# Wall time: 2min 3s

# %%
# %%time
knn = KNeighborsClassifier(n_neighbors=30, algorithm='kd_tree')
knn.fit(x_train, y_train)
predictions = knn.predict(x_test)
cm = confusion_matrix(y_test, predictions)

plt.figure(figsize = (15,10))
sns.heatmap(cm, annot=True, fmt='d')
# Out:
# CPU times: user 2.65 s, sys: 35 ms, total: 2.68 s
# Wall time: 2.6 s

# %% [markdown]
# # Task
#
# * How many complaints about different products and sub-products?
# * What are distributions of the issues and sub-issues?
# * Are there problems with the data?
# * What is the relationship between products and sub-products?
#
#
# # Minimal Deliverable
#
# * EDA + description
# * Preprocessing
# * training, testing
# * hyperparameter tuning + description
# * Classification experiments
# * Table of who worked on what
#
#
# # Extra credit
#
# * Different feature extraction and classification methods
# * Explore different input/feature combinations
# * Extra's?
